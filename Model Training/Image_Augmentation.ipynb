# %%
import os
from PIL import Image, ImageOps, ImageEnhance
import random
import numpy as np
from rembg import remove
import io

# %%
base_dir = "../datasets"
train_dir = os.path.join(base_dir, "train")

# %%
def rotate_image(image_path, save_dir, angles=[-15, -10, -5, 5, 10, 15]):
    image = Image.open(image_path)
    for angle in angles:
        rotated_image = image.rotate(angle, expand=True)
        # Save the rotated image with a new name
        base_name = os.path.basename(image_path)
        name, ext = os.path.splitext(base_name)
        new_name = f"{name}_rotated_{angle}{ext}"
        rotated_image.save(os.path.join(save_dir, new_name))

def flip_image(image_path, save_dir):
    image = Image.open(image_path)
    flipped = ImageOps.mirror(image)  # Horizontal flip
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    new_name = f"{name}_flip{ext}"
    flipped.save(os.path.join(save_dir, new_name))

# Function to scale (zoom-in) and save images
def scale_image(image_path, save_dir, scale_factor=0.9):
    image = Image.open(image_path)
    width, height = image.size
    
    # Calculate cropping box
    new_width = int(width * scale_factor)
    new_height = int(height * scale_factor)
    
    left = (width - new_width) // 2
    top = (height - new_height) // 2
    right = left + new_width
    bottom = top + new_height
    
    cropped = image.crop((left, top, right, bottom))
    scaled = cropped.resize((width, height), Image.Resampling.LANCZOS)
    
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    new_name = f"{name}_scale{ext}"
    scaled.save(os.path.join(save_dir, new_name))

def adjust_brightness(image_path, save_dir, factor_range=(0.7, 1.3)):
    image = Image.open(image_path)
    
    enhancer = ImageEnhance.Brightness(image)
    factor = random.uniform(*factor_range)  # Random brightness factor
    brightened = enhancer.enhance(factor)
    
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    factor_tag = f"{factor:.2f}".replace('.', '')
    new_name = f"{name}_bright{factor_tag}{ext}"
    brightened.save(os.path.join(save_dir, new_name))

def adjust_contrast(image_path, save_dir, factor_range=(0.7, 1.3)):
    image = Image.open(image_path)
    
    enhancer = ImageEnhance.Contrast(image)
    factor = random.uniform(*factor_range)  # Random contrast factor
    contrasted = enhancer.enhance(factor)
    
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    factor_tag = f"{factor:.2f}".replace('.', '')
    new_name = f"{name}_contrast{factor_tag}{ext}"
    contrasted.save(os.path.join(save_dir, new_name))

def add_random_noise(image_path, save_dir, noise_level=25):
    image = Image.open(image_path).convert('RGB')
    image_array = np.array(image)
    
    # Create noise
    noise = np.random.randint(-noise_level, noise_level + 1, image_array.shape, dtype='int16')
    noisy_array = image_array.astype('int16') + noise
    
    # Clip to valid pixel range
    noisy_array = np.clip(noisy_array, 0, 255).astype('uint8')
    
    noisy_image = Image.fromarray(noisy_array)
    
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    new_name = f"{name}_noise{ext}"
    noisy_image.save(os.path.join(save_dir, new_name))

def remove_background(image_path, save_dir):
    with open(image_path, "rb") as inp_file:
        input_data = inp_file.read()
        output_data = remove(input_data)
    
    output_image = Image.open(io.BytesIO(output_data)).convert("RGBA")
    
    # Save
    base_name = os.path.basename(image_path)
    name, ext = os.path.splitext(base_name)
    new_name = f"{name}_nobg.png"  # Saving as .png because it supports transparency!
    output_image.save(os.path.join(save_dir, new_name))

def generate_random_background(size, color_range=(100, 255)):
    bg_color = tuple(random.randint(*color_range) for _ in range(3))
    background = Image.new('RGB', size, bg_color)
    return background

# Function to paste PNG onto random background and save multiple versions
def paste_on_multiple_backgrounds(png_path, save_dir, num_variations=5):
    fg_image = Image.open(png_path).convert('RGBA')
    
    base_name = os.path.basename(png_path)
    name, ext = os.path.splitext(base_name)
    
    for i in range(1, num_variations + 1):
        background = generate_random_background(fg_image.size)
        
        combined = Image.alpha_composite(background.convert('RGBA'), fg_image)
        combined = combined.convert('RGB')  # For saving as JPEG (no transparency)

        new_name = f"{name}_bg{i}.jpg"
        combined.save(os.path.join(save_dir, new_name))

# %%
for class_folder in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_folder)
    if os.path.isdir(class_path):
        print(f"Augmenting class: {class_folder}")
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            # if (img_file.lower().endswith((".png", ".jpg", ".jpeg")) 
            #     and "_rot" not in img_file 
            #     and "_flip" not in img_file 
            #     and "_scale" not in img_file 
            #     and "_bright" not in img_file 
            #     and "_contrast" not in img_file
            #     and "_noise" not in img_file):
                # rotate_image(img_path, class_path)
                # flip_image(img_path, class_path)
                # scale_image(img_path, class_path)
                # adjust_brightness(img_path, class_path)
                # adjust_contrast(img_path, class_path)
                # add_random_noise(img_path, class_path)
            if "_nobg" in img_file.lower():
                # paste_on_multiple_backgrounds(img_path, class_path)
                flip_image(img_path, class_path)
# Out:
# Augmenting class: 10_Kabitham
# Augmenting class: 11_Kadagamugam
# Augmenting class: 12_Kangula
# Augmenting class: 13_Katharimugam
# Augmenting class: 14_Mayuram
# Augmenting class: 15_Mirgachirsha
# Augmenting class: 16_Mukulam
# Augmenting class: 17_Mushti
# Augmenting class: 18_Padmakosha
# Augmenting class: 19_Pathakam
# Augmenting class: 1_Alapadmam
# Augmenting class: 20_Sarpashisha
# Augmenting class: 21_Shikaram
# Augmenting class: 22_Shukathundam
# Augmenting class: 23_Simhamugha
# Augmenting class: 24_Suchi
# Augmenting class: 25_Tamaraichulam
# Augmenting class: 26_Thirpathakam
# Augmenting class: 27_Trishulam
# Augmenting class: 2_Aralam
# Augmenting class: 3_Artha chandran
# Augmenting class: 4_Arthapathakam
# Augmenting class: 5_Brahmaram
# Augmenting class: 6_Chandrakala
# Augmenting class: 7_Chaturam
# Augmenting class: 8_Hamsapaksham
# Augmenting class: 9_Hamsasiyam

# %%
# Function to delete certain type of images
def delete_rotated_images(directory):
    for class_folder in os.listdir(directory):
        class_path = os.path.join(directory, class_folder)
        if os.path.isdir(class_path):
            for img_file in os.listdir(class_path):
                # Check if filename contains the necessary tag 
                if "_scale" in img_file:
                    img_path = os.path.join(class_path, img_file)
                    os.remove(img_path)
                    print(f"Deleted: {img_path}")

# %%
delete_rotated_images(train_dir)
# Out:
# Deleted: ../datasets\train\10_Kabitham\14_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\14_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\17_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\18_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\1_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\22_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\23_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\25_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\26_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\2_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\6_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\8_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_-5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_10_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_15_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_rotated_5_scale.jpg
# Deleted: ../datasets\train\10_Kabitham\9_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\12_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\13_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\17_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\18_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\19_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\1_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\20_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\21_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\25_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\26_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\2_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\4_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_-5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_10_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_15_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_rotated_5_scale.jpg
# Deleted: ../datasets\train\11_Kadagamugam\5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\11_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\12_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\14_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\19_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\1_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\20_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\3_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\7_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_-5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_10_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_15_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_rotated_5_scale.jpg
# Deleted: ../datasets\train\12_Kangula\8_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_-5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_rotated_5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\2_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_-5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_rotated_5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_-5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_rotated_5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\6_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_-5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_10_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_15_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_rotated_5_scale.jpg
# Deleted: ../datasets\train\13_Katharimugam\7_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\11_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\13_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\14_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\18_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\2_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\3_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\4_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_-5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_10_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_15_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_rotated_5_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\6_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\7_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\7_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\14_Mayuram\7_rotated_-10_scale.jpg
# ...
# Deleted: ../datasets\train\16_Mukulam\7_rotated_-10_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_-15_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_-5_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_10_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_15_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_rotated_5_scale.jpg
# Deleted: ../datasets\train\16_Mukulam\7_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\11_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\13_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\14_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\16_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\1_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\23_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\24_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\26_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\2_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\6_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\8_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_-5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_10_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_15_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_rotated_5_scale.jpg
# Deleted: ../datasets\train\17_Mushti\9_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_-5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_rotated_5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_-5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_rotated_5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\11_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_-5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_5_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_rotated_5_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\12_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_rotated_-10_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_rotated_-10_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_rotated_-15_flip_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_rotated_-15_scale.jpg
# Deleted: ../datasets\train\18_Padmakosha\13_scale.jpg
